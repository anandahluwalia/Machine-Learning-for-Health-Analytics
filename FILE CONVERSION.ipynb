# %%
import pandas as pd

# 2000
data = pd.read_csv('hse00ai.tab', sep='\t')
data.to_csv('HSE2000.csv', index=False)

# 2001
data = pd.read_csv('hse01ai.tab', sep='\t')
data.to_csv('HSE2001.csv', index=False)

# 2002
data = pd.read_csv('hse02ai.tab', sep='\t')
data.to_csv('HSE2002.csv', index=False)

# 2003
data = pd.read_csv('hse03ai.tab', sep='\t')
data.to_csv('HSE2003.csv', index=False)

# 2004
data = pd.read_csv('hse04etha.tab', sep='\t')
data.to_csv('HSE2004.csv', index=False)

# 2005
data = pd.read_csv('hse05ai.tab', sep='\t')
data.to_csv('HSE2005.csv', index=False)

# 2006
data = pd.read_csv('hse06ai.tab', sep='\t')
data.to_csv('HSE2006.csv', index=False)

# 2007
data = pd.read_csv('hse07ai.tab', sep='\t')
data.to_csv('HSE2007.csv', index=False)

# 2008
data = pd.read_csv('hse08ai.tab', sep='\t')
data.to_csv('HSE2008.csv', index=False)

# 2009
data = pd.read_csv('hse09ai.tab', sep='\t')
data.to_csv('HSE2009.csv', index=False)

# 2010
data = pd.read_csv('hse10ai.tab', sep='\t')
data.to_csv('HSE2010.csv', index=False)

# 2011
data = pd.read_csv('hse2011ai.tab', sep='\t')
data.to_csv('HSE2011.csv', index=False)

# 2012
data = pd.read_csv('hse2012ai.tab', sep='\t')
data.to_csv('HSE2012.csv', index=False)

# 2013
data = pd.read_csv('hse2013ai.tab', sep='\t')
data.to_csv('HSE2013.csv', index=False)

# 2014
data = pd.read_csv('hse2014ai.tab', sep='\t')
data.to_csv('HSE2014.csv', index=False)

# 2015
data = pd.read_csv('hse2015ai.tab', sep='\t')
data.to_csv('HSE2015.csv', index=False)

# 2016
data = pd.read_csv('hse16_eul_v5.tab', sep='\t')
data.to_csv('HSE2016.csv', index=False)

# 2017
data = pd.read_csv('hse17i_eul_v3.tab', sep='\t')
data.to_csv('HSE2017.csv', index=False)

# 2018
data = pd.read_csv('hse_2018_eul_15082022.tab', sep='\t')
data.to_csv('HSE2018.csv', index=False)

# 2019
data = pd.read_csv('hse_2019_eul_20211006.tab', sep='\t')
data.to_csv('HSE2019.csv', index=False)

print("Conversion complete.")
# Out:
# Conversion complete.
