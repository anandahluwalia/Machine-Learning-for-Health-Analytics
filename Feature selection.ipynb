# %%
import pandas as pd
import numpy as np

data = pd.read_csv('HSE2005.csv')

selected_columns5 = ['pserial','sex','ethinda', 'ag16g10', 'height','cigst1', 'weight', 'cigdyal',
                    'adrinkwq', 'diabete2','insulin','omdiaval', 'omsysval',
                    'hdlval','cholest']  
selected_data5 = data[selected_columns5]



selected_data5.to_csv('DiaHSE2005.csv', index=False)

df1 = pd.read_csv('DiaHSE2005.csv')
position1 = 10
df1.insert(position1, 'Type',np.nan)
df1.to_csv('DiaHSE2005.csv', index=False)

df1 = pd.read_csv('DiaHSE2005.csv')
position1 = 12
df1.insert(position1, 'Diab3mmolg',np.nan)
df1.to_csv('DiaHSE2005.csv', index=False)
df1 = pd.read_csv('DiaHSE2005.csv')

position1 = 13
df1.insert(position1, 'IFCCA1',np.nan)
df1.to_csv('DiaHSE2005.csv', index=False)



def change_column_names(csv_file, new_column_names):
    df = pd.read_csv(csv_file)
    df.columns = new_column_names
    df.to_csv(csv_file, index=False)

csv_file = 'DiaHSE2005.csv'
new_column_names = ['Serial', 'Sex','Origin', 'Age', 'Height','Cigrette', 'Weight', 'CigUnit',
                    'AlcoholUnit', 'Diabetes', 'Type','Insulin', 'Diab3mmolg', 'IFCCA1','OmDiast', 'OmSyst',
                    'HDLChol','Cholest']    # New column names

change_column_names(csv_file, new_column_names)

df2 = pd.read_csv('DiaHSE2005.csv')
new_column_data2 = ['2005'] * len(df2)  # Change 'data_value' to your desired value
positionyear = 1
df2.insert(positionyear, 'Year', new_column_data2)
df2.to_csv('DiaHSE2005.csv', index=False)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
data = pd.read_csv('HSE2006.csv')

selected_columns6 = ['pserial','sex','ethinda', 'ag16g10', 'height','cigst1', 'weight', 'cigdyal',
                    'adrinkwq', 'diabete2','insulin','omdiaval', 'omsysval',
                    'hdlval','cholest'] 
selected_data6 = data[selected_columns6]

selected_data6.to_csv('DiaHSE2006.csv', index=False) 

df1 = pd.read_csv('DiaHSE2006.csv')
position1 = 10
df1.insert(position1, 'Type',np.nan)
df1.to_csv('DiaHSE2006.csv', index=False)

df1 = pd.read_csv('DiaHSE2006.csv')
position1 = 12
df1.insert(position1, 'Diab3mmolg',np.nan)
df1.to_csv('DiaHSE2006.csv', index=False)
df1 = pd.read_csv('DiaHSE2006.csv')

position1 = 13
df1.insert(position1, 'IFCCA1',np.nan)
df1.to_csv('DiaHSE2006.csv', index=False)



def change_column_names(csv_file, new_column_names):
    df = pd.read_csv(csv_file)
    df.columns = new_column_names
    df.to_csv(csv_file, index=False)

# Example usage:
csv_file = 'DiaHSE2006.csv'
new_column_names = ['Serial', 'Sex','Origin', 'Age', 'Height','Cigrette', 'Weight', 'CigUnit',
                    'AlcoholUnit', 'Diabetes', 'Type','Insulin', 'Diab3mmolg', 'IFCCA1','OmDiast', 'OmSyst',
                    'HDLChol','Cholest']    # New column names

change_column_names(csv_file, new_column_names)
df2 = pd.read_csv('DiaHSE2006.csv')
new_column_data2 = ['2006'] * len(df2)  # Change 'data_value' to your desired value
positionyear = 1
df2.insert(positionyear, 'Year', new_column_data2)
df2.to_csv('DiaHSE2006.csv', index=False)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
data = pd.read_csv('HSE2007.csv')

selected_columns7 =['pserial','sex','ethinda', 'ag16g10', 'height','cigst1', 'weight', 'cigdyal',
                    'adrkwq07', 'cdiabete','cinsulin','omdiaval', 'omsysval','ketegga']
selected_data7 = data[selected_columns7]
selected_data7.to_csv('DiaHSE2007.csv', index=False) 


df1 = pd.read_csv('DiaHSE2007.csv')
position1 = 10
df1.insert(position1, 'Type',np.nan)
df1.to_csv('DiaHSE2007.csv', index=False)
df1 = pd.read_csv('DiaHSE2007.csv')
position1 = 12
df1.insert(position1, 'Diab3mmolg',np.nan)
df1.to_csv('DiaHSE2007.csv', index=False)
df1 = pd.read_csv('DiaHSE2007.csv')
position1 = 13
df1.insert(position1, 'IFCCA1',np.nan)
df1.to_csv('DiaHSE2007.csv', index=False)
df1 = pd.read_csv('DiaHSE2007.csv')
position1 = 16
df1.insert(position1, 'HDLChol',np.nan)
df1.to_csv('DiaHSE2007.csv', index=False)



def change_column_names(csv_file, new_column_names):
    df = pd.read_csv(csv_file)
    df.columns = new_column_names
    df.to_csv(csv_file, index=False)

csv_file = 'DiaHSE2007.csv'
new_column_names = ['Serial', 'Sex','Origin', 'Age', 'Height','Cigrette', 'Weight', 'CigUnit',
                    'AlcoholUnit', 'Diabetes', 'Type','Insulin', 'Diab3mmolg', 'IFCCA1','OmDiast', 'OmSyst',
                    'HDLChol','Cholest']    # New column names

change_column_names(csv_file, new_column_names)
df2 = pd.read_csv('DiaHSE2007.csv')
new_column_data2 = ['2007'] * len(df2)  # Change 'data_value' to your desired value
positionyear = 1
df2.insert(positionyear, 'Year', new_column_data2)
df2.to_csv('DiaHSE2007.csv', index=False)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
data = pd.read_csv('HSE2008.csv')

selected_columns8 = ['pserial','sex','origin', 'ag16g10', 'height','cigst1', 'weight', 'cigdyal',
                    'alclimit07B', 'cdiabete','cinsulin','omdiaval', 'omsysval','cholest']
selected_data8 = data[selected_columns8]


selected_data8.to_csv('DiaHSE2008.csv', index=False)

['Serial', 'Sex','Origin', 'Age', 'Height','Cigrette', 'Weight', 'CigUnit',
                    'AlcoholUnit', 'Diabetes', 'Type','Insulin', 'Diab3mmolg', 'IFCCA1','OmDiast', 'OmSyst',
                    'HDLChol','Cholest'] 


df1 = pd.read_csv('DiaHSE2008.csv')
position1 = 10
df1.insert(position1, 'Type',np.nan)
df1.to_csv('DiaHSE2008.csv', index=False)
df1 = pd.read_csv('DiaHSE2008.csv')
position1 = 12
df1.insert(position1, 'Diab3mmolg',np.nan)
df1.to_csv('DiaHSE2008.csv', index=False)
df1 = pd.read_csv('DiaHSE2008.csv')
position1 = 13
df1.insert(position1, 'IFCCA1',np.nan)
df1.to_csv('DiaHSE2008.csv', index=False)
df1 = pd.read_csv('DiaHSE2008.csv')
position1 = 16
df1.insert(position1, 'HDLChol',np.nan)
df1.to_csv('DiaHSE2008.csv', index=False)



def change_column_names(csv_file, new_column_names):
    df = pd.read_csv(csv_file)
    df.columns = new_column_names
    df.to_csv(csv_file, index=False)

# Example usage:
csv_file = 'DiaHSE2008.csv'
new_column_names = ['Serial', 'Sex','Origin', 'Age', 'Height','Cigrette', 'Weight', 'CigUnit',
                    'AlcoholUnit', 'Diabetes', 'Type','Insulin', 'Diab3mmolg', 'IFCCA1','OmDiast', 'OmSyst',
                    'HDLChol','Cholest']    # New column names

change_column_names(csv_file, new_column_names)
df2 = pd.read_csv('DiaHSE2008.csv')
new_column_data2 = ['2008'] * len(df2)  # Change 'data_value' to your desired value
positionyear = 1
df2.insert(positionyear, 'Year', new_column_data2)
df2.to_csv('DiaHSE2008.csv', index=False)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
data = pd.read_csv('HSE2009.csv')

selected_columns9 = ['pserial','sex','origin', 'ag16g10', 'height','cigst1', 'weight', 'cigdyal',
                    'adrkwq08', 'diabetes','insulin','omdiaval', 'omsysval','cholest'] 
selected_data9 = data[selected_columns9]
selected_data9.to_csv('DiaHSE2009.csv', index=False)  

df1 = pd.read_csv('DiaHSE2009.csv')
position1 = 10
df1.insert(position1, 'Type',np.nan)
df1.to_csv('DiaHSE2009.csv', index=False)
df1 = pd.read_csv('DiaHSE2009.csv')
position1 = 12
df1.insert(position1, 'Diab3mmolg',np.nan)
df1.to_csv('DiaHSE2009.csv', index=False)
df1 = pd.read_csv('DiaHSE2009.csv')
position1 = 13
df1.insert(position1, 'IFCCA1',np.nan)
df1.to_csv('DiaHSE2009.csv', index=False)
df1 = pd.read_csv('DiaHSE2009.csv')
position1 = 16
df1.insert(position1, 'HDLChol',np.nan)
df1.to_csv('DiaHSE2009.csv', index=False)



def change_column_names(csv_file, new_column_names):
    df = pd.read_csv(csv_file)
    df.columns = new_column_names
    df.to_csv(csv_file, index=False)

# Example usage:
csv_file = 'DiaHSE2009.csv'
new_column_names = ['Serial', 'Sex','Origin', 'Age', 'Height','Cigrette', 'Weight', 'CigUnit',
                    'AlcoholUnit', 'Diabetes', 'Type','Insulin', 'Diab3mmolg', 'IFCCA1','OmDiast', 'OmSyst',
                    'HDLChol','Cholest']   

change_column_names(csv_file, new_column_names)
df2 = pd.read_csv('DiaHSE2009.csv')
new_column_data2 = ['2009'] * len(df2)  # Change 'data_value' to your desired value
positionyear = 1
df2.insert(positionyear, 'Year', new_column_data2)
df2.to_csv('DiaHSE2009.csv', index=False)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
data = pd.read_csv('HSE2010.csv')

selected_columns10 = ['pserial','sex','origin', 'ag16g10', 'height','cigst1', 'weight', 'cigdyal',
                    'alclimit07b', 'diabetes','insulin','omdiaval', 'omsysval','cholest']
selected_data10 = data[selected_columns10]

selected_data10.to_csv('DiaHSE2010.csv', index=False) 

df1 = pd.read_csv('DiaHSE2010.csv')
position1 = 10
df1.insert(position1, 'Type',np.nan)
df1.to_csv('DiaHSE2010.csv', index=False)
df1 = pd.read_csv('DiaHSE2010.csv')
position1 = 12
df1.insert(position1, 'Diab3mmolg',np.nan)
df1.to_csv('DiaHSE2010.csv', index=False)
df1 = pd.read_csv('DiaHSE2010.csv')
position1 = 13
df1.insert(position1, 'IFCCA1',np.nan)
df1.to_csv('DiaHSE2010.csv', index=False)
df1 = pd.read_csv('DiaHSE2010.csv')
position1 = 16
df1.insert(position1, 'HDLChol',np.nan)
df1.to_csv('DiaHSE2010.csv', index=False)



def change_column_names(csv_file, new_column_names):
    df = pd.read_csv(csv_file)
    df.columns = new_column_names
    df.to_csv(csv_file, index=False)

# Example usage:
csv_file = 'DiaHSE2010.csv'
new_column_names = ['Serial', 'Sex','Origin', 'Age', 'Height','Cigrette', 'Weight', 'CigUnit',
                    'AlcoholUnit', 'Diabetes', 'Type','Insulin', 'Diab3mmolg', 'IFCCA1','OmDiast', 'OmSyst',
                    'HDLChol','Cholest']    # New column names

change_column_names(csv_file, new_column_names)
df2 = pd.read_csv('DiaHSE2010.csv')
new_column_data2 = ['2010'] * len(df2)  # Change 'data_value' to your desired value
positionyear = 1
df2.insert(positionyear, 'Year', new_column_data2)
df2.to_csv('DiaHSE2010.csv', index=False)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
data = pd.read_csv('HSE2011.csv')

selected_columns11 = ['pserial','Sex','Origin', 'ag16g10', 'Height','cigst1', 'Weight', 'cigdyal',
                    'totalwug', 'docinfo1','diabtype','insulin', 'omdiaval', 'omsysval',
                    'Cholest']  
selected_data11 = data[selected_columns11]
selected_data11.to_csv('DiaHSE2011.csv', index=False) 

df1 = pd.read_csv('DiaHSE2011.csv')
position1 = 12
df1.insert(position1, 'Diab3mmolg',np.nan)
df1.to_csv('DiaHSE2011.csv', index=False)
df1 = pd.read_csv('DiaHSE2011.csv')
position1 = 13
df1.insert(position1, 'IFCCA1',np.nan)
df1.to_csv('DiaHSE2011.csv', index=False)
df1 = pd.read_csv('DiaHSE2011.csv')
position1 = 16
df1.insert(position1, 'HDLChol',np.nan)
df1.to_csv('DiaHSE2011.csv', index=False)



def change_column_names(csv_file, new_column_names):
    df = pd.read_csv(csv_file)

    # Set new column names
    df.columns = new_column_names

    # Write the DataFrame back to the CSV file
    df.to_csv(csv_file, index=False)

# Example usage:
csv_file = 'DiaHSE2011.csv'
new_column_names = ['Serial', 'Sex','Origin', 'Age', 'Height','Cigrette', 'Weight', 'CigUnit',
                    'AlcoholUnit', 'Diabetes', 'Type','Insulin', 'Diab3mmolg', 'IFCCA1','OmDiast', 'OmSyst',
                    'HDLChol','Cholest']    # New column names

change_column_names(csv_file, new_column_names)
df2 = pd.read_csv('DiaHSE2011.csv')
new_column_data2 = ['2011'] * len(df2)  # Change 'data_value' to your desired value
positionyear = 1
df2.insert(positionyear, 'Year', new_column_data2)
df2.to_csv('DiaHSE2011.csv', index=False)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
data = pd.read_csv('HSE2012.csv')

selected_columns12 = ['pserial','Sex','Origin', 'ag16g10', 'Height','cigst1', 'Weight', 'cigdyal',
                    'totalwug', 'diabete2','diabtype','Insulin', 'omdiaval', 'omsysval',
                    'Cholest']   
selected_data12 = data[selected_columns12]
#2011
selected_data12.to_csv('DiaHSE2012.csv', index=False) 

df1 = pd.read_csv('DiaHSE2012.csv')
position1 = 12
df1.insert(position1, 'Diab3mmolg',np.nan)
df1.to_csv('DiaHSE2012.csv', index=False)
df1 = pd.read_csv('DiaHSE2012.csv')
position1 = 13
df1.insert(position1, 'IFCCA1',np.nan)
df1.to_csv('DiaHSE2012.csv', index=False)
df1 = pd.read_csv('DiaHSE2012.csv')
position1 = 16
df1.insert(position1, 'HDLChol',np.nan)
df1.to_csv('DiaHSE2012.csv', index=False)



def change_column_names(csv_file, new_column_names):
    df = pd.read_csv(csv_file)
    df.columns = new_column_names
    df.to_csv(csv_file, index=False)

# Example usage:
csv_file = 'DiaHSE2012.csv'
new_column_names = ['Serial', 'Sex','Origin', 'Age', 'Height','Cigrette', 'Weight', 'CigUnit',
                    'AlcoholUnit', 'Diabetes', 'Type','Insulin', 'Diab3mmolg', 'IFCCA1','OmDiast', 'OmSyst',
                    'HDLChol','Cholest']    # New column names

change_column_names(csv_file, new_column_names)
df2 = pd.read_csv('DiaHSE2012.csv')
new_column_data2 = ['2012'] * len(df2)  # Change 'data_value' to your desired value
positionyear = 1
df2.insert(positionyear, 'Year', new_column_data2)
df2.to_csv('DiaHSE2012.csv', index=False)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
data = pd.read_csv('HSE2013.csv')

selected_columns13 = ['pserial','Sex','Origin', 'ag16g10', 'Height','cigst1', 'Weight', 'cigdyal',
                    'totalwug', 'diabete2','diabtype','Insulin', 'omdiaval', 'omsysval',
                    'Cholest']  
selected_data13 = data[selected_columns13]
#2011
selected_data13.to_csv('DiaHSE2013.csv', index=False)

df1 = pd.read_csv('DiaHSE2013.csv')
position1 = 12
df1.insert(position1, 'Diab3mmolg',np.nan)
df1.to_csv('DiaHSE2013.csv', index=False)
df1 = pd.read_csv('DiaHSE2013.csv')
position1 = 13
df1.insert(position1, 'IFCCA1',np.nan)
df1.to_csv('DiaHSE2013.csv', index=False)
df1 = pd.read_csv('DiaHSE2013.csv')
position1 = 16
df1.insert(position1, 'HDLChol',np.nan)
df1.to_csv('DiaHSE2013.csv', index=False)



def change_column_names(csv_file, new_column_names):
    df = pd.read_csv(csv_file)
    df.columns = new_column_names
    df.to_csv(csv_file, index=False)

csv_file = 'DiaHSE2013.csv'
new_column_names = ['Serial', 'Sex','Origin', 'Age', 'Height','Cigrette', 'Weight', 'CigUnit',
                    'AlcoholUnit', 'Diabetes', 'Type','Insulin', 'Diab3mmolg', 'IFCCA1','OmDiast', 'OmSyst',
                    'HDLChol','Cholest']    # New column names

change_column_names(csv_file, new_column_names)
df2 = pd.read_csv('DiaHSE2013.csv')
new_column_data2 = ['2013'] * len(df2)  # Change 'data_value' to your desired value
positionyear = 1
df2.insert(positionyear, 'Year', new_column_data2)
df2.to_csv('DiaHSE2013.csv', index=False)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
data = pd.read_csv('HSE2014.csv')

selected_columns14 = ['pserial','Sex','Origin3', 'ag16g10', 'Height','cigst1', 'Weight', 'cigdyal',
                    'totalwug', 'diabete2','diabtype','Insulin', 'omdiaval', 'omsysval',
                    'Cholest']    
selected_data14 = data[selected_columns14]
#2011

selected_data14.to_csv('DiaHSE2014.csv', index=False)  

df1 = pd.read_csv('DiaHSE2014.csv')
position1 = 12
df1.insert(position1, 'Diab3mmolg',np.nan)
df1.to_csv('DiaHSE2014.csv', index=False)
df1 = pd.read_csv('DiaHSE2014.csv')
position1 = 13
df1.insert(position1, 'IFCCA1',np.nan)
df1.to_csv('DiaHSE2014.csv', index=False)
df1 = pd.read_csv('DiaHSE2014.csv')
position1 = 16
df1.insert(position1, 'HDLChol',np.nan)
df1.to_csv('DiaHSE2014.csv', index=False)



def change_column_names(csv_file, new_column_names):
    df = pd.read_csv(csv_file)
    df.columns = new_column_names
    df.to_csv(csv_file, index=False)

csv_file = 'DiaHSE2014.csv'
new_column_names = ['Serial', 'Sex','Origin', 'Age', 'Height','Cigrette', 'Weight', 'CigUnit',
                    'AlcoholUnit', 'Diabetes', 'Type','Insulin', 'Diab3mmolg', 'IFCCA1','OmDiast', 'OmSyst',
                    'HDLChol','Cholest']    

change_column_names(csv_file, new_column_names)
df2 = pd.read_csv('DiaHSE2014.csv')
new_column_data2 = ['2014'] * len(df2)  # Change 'data_value' to your desired value
positionyear = 1
df2.insert(positionyear, 'Year', new_column_data2)
df2.to_csv('DiaHSE2014.csv', index=False)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
data = pd.read_csv('HSE2015.csv')

selected_columns15 = ['SerialA','Sex','origin2', 'ag16g10', 'Height','cigst1', 'Weight', 'cigdyal',
                    'totalwug', 'diabete2','diabtype','Insulin', 'omdiaval', 'omsysval',
                    'Cholest']   
selected_data15 = data[selected_columns15]
selected_data15.to_csv('DiaHSE2015.csv', index=False) 

df1 = pd.read_csv('DiaHSE2015.csv')
position1 = 12
df1.insert(position1, 'Diab3mmolg',np.nan)
df1.to_csv('DiaHSE2015.csv', index=False)
df1 = pd.read_csv('DiaHSE2015.csv')
position1 = 13
df1.insert(position1, 'IFCCA1',np.nan)
df1.to_csv('DiaHSE2015.csv', index=False)
df1 = pd.read_csv('DiaHSE2015.csv')
position1 = 16
df1.insert(position1, 'HDLChol',np.nan)
df1.to_csv('DiaHSE2015.csv', index=False)



def change_column_names(csv_file, new_column_names):
    df = pd.read_csv(csv_file)
    df.columns = new_column_names
    df.to_csv(csv_file, index=False)

# Example usage:
csv_file = 'DiaHSE2015.csv'
new_column_names = ['Serial', 'Sex','Origin', 'Age', 'Height','Cigrette', 'Weight', 'CigUnit',
                    'AlcoholUnit', 'Diabetes', 'Type','Insulin', 'Diab3mmolg', 'IFCCA1','OmDiast', 'OmSyst',
                    'HDLChol','Cholest']    # New column names

change_column_names(csv_file, new_column_names)

df2 = pd.read_csv('DiaHSE2015.csv')
new_column_data2 = ['2015'] * len(df2)  # Change 'data_value' to your desired value
positionyear = 1
df2.insert(positionyear, 'Year', new_column_data2)
df2.to_csv('DiaHSE2015.csv', index=False)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
data = pd.read_csv('HSE2016.csv')

selected_columns16 = ['SerialA','Sex','Origin2', 'ag16g10', 'Height','cigst1', 'Weight', 'cigdyal',
                    'totalwug', 'diabete2','diabtype','Insulin', 'omdiaval', 'omsysval',
                    'Cholest']    
selected_data16 = data[selected_columns16]
#2011 PSERIAL
selected_data16.to_csv('DiaHSE2016.csv', index=False) 

df1 = pd.read_csv('DiaHSE2016.csv')
position1 = 12
df1.insert(position1, 'Diab3mmolg',np.nan)
df1.to_csv('DiaHSE2016.csv', index=False)
df1 = pd.read_csv('DiaHSE2016.csv')
position1 = 13
df1.insert(position1, 'IFCCA1',np.nan)
df1.to_csv('DiaHSE2016.csv', index=False)
df1 = pd.read_csv('DiaHSE2016.csv')
position1 = 16
df1.insert(position1, 'HDLChol',np.nan)
df1.to_csv('DiaHSE2016.csv', index=False)



def change_column_names(csv_file, new_column_names):
    df = pd.read_csv(csv_file)
    df.columns = new_column_names
    df.to_csv(csv_file, index=False)

# Example usage:
csv_file = 'DiaHSE2016.csv'
new_column_names = ['Serial', 'Sex','Origin', 'Age', 'Height','Cigrette', 'Weight', 'CigUnit',
                    'AlcoholUnit', 'Diabetes', 'Type','Insulin', 'Diab3mmolg', 'IFCCA1','OmDiast', 'OmSyst',
                    'HDLChol','Cholest']    # New column names

change_column_names(csv_file, new_column_names)
df2 = pd.read_csv('DiaHSE2016.csv')
new_column_data2 = ['2016'] * len(df2)  # Change 'data_value' to your desired value
positionyear = 1
df2.insert(positionyear, 'Year', new_column_data2)
df2.to_csv('DiaHSE2016.csv', index=False)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
data = pd.read_csv('HSE2017.csv')

selected_columns17 = ['SerialA','Sex','Origin2', 'ag16g10', 'Height','cigst1', 'Weight', 'cigdyal',
                    'totalwug', 'diabete2','diabtype','cinsulin', 'omdiaval', 'omsysval',
                    'Cholest']     
selected_data17 = data[selected_columns17]
#2016
selected_data17.to_csv('DiaHSE2017.csv', index=False) 

df1 = pd.read_csv('DiaHSE2017.csv')
position1 = 12
df1.insert(position1, 'Diab3mmolg',np.nan)
df1.to_csv('DiaHSE2017.csv', index=False)
df1 = pd.read_csv('DiaHSE2017.csv')
position1 = 13
df1.insert(position1, 'IFCCA1',np.nan)
df1.to_csv('DiaHSE2017.csv', index=False)
df1 = pd.read_csv('DiaHSE2017.csv')
position1 = 16
df1.insert(position1, 'HDLChol',np.nan)
df1.to_csv('DiaHSE2017.csv', index=False)



def change_column_names(csv_file, new_column_names):
    df = pd.read_csv(csv_file)
    df.columns = new_column_names
    df.to_csv(csv_file, index=False)

# Example usage:
csv_file = 'DiaHSE2017.csv'
new_column_names = ['Serial', 'Sex','Origin', 'Age', 'Height','Cigrette', 'Weight', 'CigUnit',
                    'AlcoholUnit', 'Diabetes', 'Type','Insulin', 'Diab3mmolg', 'IFCCA1','OmDiast', 'OmSyst',
                    'HDLChol','Cholest']    # New column names

change_column_names(csv_file, new_column_names)

df2 = pd.read_csv('DiaHSE2017.csv')
new_column_data2 = ['2017'] * len(df2)  # Change 'data_value' to your desired value
positionyear = 1
df2.insert(positionyear, 'Year', new_column_data2)
df2.to_csv('DiaHSE2017.csv', index=False)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
data = pd.read_csv('HSE2018.csv')

selected_columns18 = ['Seriala','Sex','origin2', 'ag16g10', 'Height','cigst1', 'Weight', 'cigdyal',
                    'totalwug', 'diabete2','diabtype','Insulin', 'omdiaval', 'omsysval',
                    'Cholest']    
selected_data18 = data[selected_columns18]
#2016
selected_data18.to_csv('DiaHSE2018.csv', index=False) 

df1 = pd.read_csv('DiaHSE2018.csv')
position1 = 12
df1.insert(position1, 'Diab3mmolg',np.nan)
df1.to_csv('DiaHSE2018.csv', index=False)
df1 = pd.read_csv('DiaHSE2018.csv')
position1 = 13
df1.insert(position1, 'IFCCA1',np.nan)
df1.to_csv('DiaHSE2018.csv', index=False)
df1 = pd.read_csv('DiaHSE2018.csv')
position1 = 16
df1.insert(position1, 'HDLChol',np.nan)
df1.to_csv('DiaHSE2018.csv', index=False)



def change_column_names(csv_file, new_column_names):
    df = pd.read_csv(csv_file)
    df.columns = new_column_names
    df.to_csv(csv_file, index=False)

# Example usage:
csv_file = 'DiaHSE2018.csv'
new_column_names = ['Serial', 'Sex','Origin', 'Age', 'Height','Cigrette', 'Weight', 'CigUnit',
                    'AlcoholUnit', 'Diabetes', 'Type','Insulin', 'Diab3mmolg', 'IFCCA1','OmDiast', 'OmSyst',
                    'HDLChol','Cholest']    # New column names

change_column_names(csv_file, new_column_names)
df2 = pd.read_csv('DiaHSE2018.csv')
new_column_data2 = ['2018'] * len(df2)  # Change 'data_value' to your desired value
positionyear = 1
df2.insert(positionyear, 'Year', new_column_data2)
df2.to_csv('DiaHSE2018.csv', index=False)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

data = pd.read_csv('HSE2019.csv')

selected_columns19 = ['SerialA', 'Sex','origin2', 'age16g5', 'Height','cigst1_19', 'Weight', 'cigdyal_19',
                    'alclimit7B_19', 'Diabetes', 'TypeD','Insulin', 'diab3mmolg', 'IFCCA1','OmDiast', 'OmSyst',
                    'HDLChol','Cholest']  
selected_data19 = data[selected_columns19]

selected_data19.to_csv('DiaHSE2019.csv', index=False)


def change_column_names(csv_file, new_column_names):
    df = pd.read_csv(csv_file)
    df.columns = new_column_names
    df.to_csv(csv_file, index=False)

# Example usage:
csv_file = 'DiaHSE2019.csv'
new_column_names = ['Serial', 'Sex','Origin', 'Age', 'Height','Cigrette', 'Weight', 'CigUnit',
                    'AlcoholUnit', 'Diabetes', 'Type','Insulin', 'Diab3mmolg', 'IFCCA1','OmDiast', 'OmSyst',
                    'HDLChol','Cholest']    # New column names

change_column_names(csv_file, new_column_names)

df2 = pd.read_csv('DiaHSE2019.csv')
new_column_data2 = ['2019'] * len(df2)  # Change 'data_value' to your desired value
positionyear = 1
df2.insert(positionyear, 'Year', new_column_data2)
df2.to_csv('DiaHSE2019.csv', index=False)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

print("saved")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2060\4240649576.py:4: DtypeWarning: Columns (207,249,251,618,1175,1190,1191,1192) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('HSE2000.csv')
# C:\Users\user\AppData\Local\Temp\ipykernel_2060\4240649576.py:118: DtypeWarning: Columns (247) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('HSE2003.csv')
# C:\Users\user\AppData\Local\Temp\ipykernel_2060\4240649576.py:297: DtypeWarning: Columns (1889,2136) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('HSE2007.csv')
# C:\Users\user\AppData\Local\Temp\ipykernel_2060\4240649576.py:341: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('HSE2008.csv')
# ...

# %% [markdown]
# "['sex', 'ethinda', 'height', 'weight', 'adrkwq07', 'cdiabete', 'cinsulin', 'ketegga']

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('HSE2019.csv')

selected_columns19 = ['SerialA', 'Sex','origin2', 'age16g5', 'Height','cigst1_19', 'Weight', 'cigdyal_19',
                    'alclimit7B_19', 'Diabetes', 'TypeD','Insulin', 'diab3mmolg', 'IFCCA1','OmDiast', 'OmSyst',
                    'HDLChol','Cholest']  
selected_data19 = data[selected_columns19]

selected_data19.to_csv('DiaHSE2019.csv', index=False)


def change_column_names(csv_file, new_column_names):
    df = pd.read_csv(csv_file)
    df.columns = new_column_names
    df.to_csv(csv_file, index=False)

# Example usage:
csv_file = 'DiaHSE2019.csv'
new_column_names = ['Serial', 'Sex','Origin', 'Age', 'Height','Cigrette', 'Weight', 'CigUnit',
                    'AlcoholUnit', 'Diabetes', 'Type','Insulin', 'Diab3mmolg', 'IFCCA1','OmDiast', 'OmSyst',
                    'HDLChol','Cholest']    # New column names

change_column_names(csv_file, new_column_names)

df2 = pd.read_csv('DiaHSE2019.csv')
new_column_data2 = ['2019'] * len(df2)  # Change 'data_value' to your desired value
positionyear = 1
df2.insert(positionyear, 'Year', new_column_data2)
df2.to_csv('DiaHSE2019.csv', index=False)
